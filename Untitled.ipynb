# %%
from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit.primitives import Estimator
from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import SLSQP
from qiskit_nature.second_q.circuit.library import HartreeFock, UCCSD
from qiskit_nature.second_q.algorithms import GroundStateEigensolver

# 1. Define the molecule and driver
driver = PySCFDriver(
    atom="H 0 0 0; H 0 0 0.735",
    unit=DistanceUnit.ANGSTROM,
    basis="sto3g",
    charge=0,
    spin=0,
)
problem = driver.run()

# 2. Define mapper
mapper = ParityMapper()

# 3. Setup Hartree-Fock and UCCSD ansatz
num_particles = problem.num_particles
num_spatial_orbitals = problem.num_spatial_orbitals

initial_state = HartreeFock(
    num_spatial_orbitals=num_spatial_orbitals,
    num_particles=num_particles,
    qubit_mapper=mapper,
)

ansatz = UCCSD(
    num_spatial_orbitals=num_spatial_orbitals,
    num_particles=num_particles,
    qubit_mapper=mapper,
    initial_state=initial_state,
)

# 4. Set up VQE
estimator = Estimator()
optimizer = SLSQP()
vqe_solver = VQE(estimator=estimator, ansatz=ansatz, optimizer=optimizer)
vqe_solver.initial_point = [0.0] * ansatz.num_parameters

# 5. Solve the ground state problem
solver = GroundStateEigensolver(mapper, vqe_solver)
result = solver.solve(problem)

# 6. Print result
print(f"Ground state energy: {result.total_energies[0]:.6f} Ha")
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1241/788747977.py", line 1, in <module>
#     from qiskit_nature.units import DistanceUnit
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/qiskit_nature/__init__.py", line 52, in <module>
#     from qiskit.algorithms.minimum_eigen_solvers.minimum_eigen_solver import (
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/qiskit/algorithms/__init__.py", line 308, in <module>
#     from .evolvers import EvolutionResult, EvolutionProblem
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/qiskit/algorithms/evolvers/__init__.py", line 15, in <module>
#     from .evolution_result import EvolutionResult
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/qiskit/algorithms/evolvers/evolution_result.py", line 19, in <module>
#     from qiskit.opflow import StateFn, OperatorBase
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/qiskit/opflow/__init__.py", line 175, in <module>
#     from .state_fns import (
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/qiskit/opflow/state_fns/__init__.py", line 65, in <module>
#     from .operator_state_fn import OperatorStateFn
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/qiskit/opflow/state_fns/operator_state_fn.py", line 27, in <module>
#     from qiskit.opflow.state_fns.circuit_state_fn import CircuitStateFn
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/qiskit/opflow/state_fns/circuit_state_fn.py", line 20, in <module>
#     from qiskit import (  # pylint: disable=no-name-in-module
# ImportError: cannot import name 'BasicAer' from 'qiskit' (/home/anudeep/anaconda3/lib/python3.11/site-packages/qiskit/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#            ^^^^^
#   File "/home/anudeep/anaconda3/lib/python3.11/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
pip install "qiskit-nature==0.5.2" "qiskit-algorithms==0.2.1"
# Out:
# Collecting qiskit-nature==0.5.2
#   Downloading qiskit_nature-0.5.2-py3-none-any.whl.metadata (9.8 kB)
# Collecting qiskit-algorithms==0.2.1
#   Downloading qiskit_algorithms-0.2.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting qiskit-terra>=0.22.* (from qiskit-nature==0.5.2)
#   Downloading qiskit_terra-0.46.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: scipy>=1.4 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-nature==0.5.2) (1.11.4)
# Requirement already satisfied: numpy>=1.17 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-nature==0.5.2) (1.26.4)
# Requirement already satisfied: psutil>=5 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-nature==0.5.2) (5.9.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-nature==0.5.2) (1.2.2)
# Requirement already satisfied: setuptools>=40.1.0 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-nature==0.5.2) (68.2.2)
# Requirement already satisfied: typing-extensions in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-nature==0.5.2) (4.9.0)
# Requirement already satisfied: h5py in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-nature==0.5.2) (3.9.0)
# Requirement already satisfied: rustworkx in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-nature==0.5.2) (0.16.0)
# Requirement already satisfied: ply>=3.10 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-terra>=0.22.*->qiskit-nature==0.5.2) (3.11)
# Requirement already satisfied: sympy>=1.3 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-terra>=0.22.*->qiskit-nature==0.5.2) (1.12)
# Requirement already satisfied: dill>=0.3 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-terra>=0.22.*->qiskit-nature==0.5.2) (0.3.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-terra>=0.22.*->qiskit-nature==0.5.2) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-terra>=0.22.*->qiskit-nature==0.5.2) (5.4.1)
# Requirement already satisfied: symengine>=0.11 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from qiskit-terra>=0.22.*->qiskit-nature==0.5.2) (0.13.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.0->qiskit-nature==0.5.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.0->qiskit-nature==0.5.2) (2.2.0)
# Requirement already satisfied: six>=1.5 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit-terra>=0.22.*->qiskit-nature==0.5.2) (1.16.0)
# Requirement already satisfied: pbr>=2.0.0 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit-terra>=0.22.*->qiskit-nature==0.5.2) (6.1.1)
# Requirement already satisfied: mpmath>=0.19 in /home/anudeep/anaconda3/lib/python3.11/site-packages (from sympy>=1.3->qiskit-terra>=0.22.*->qiskit-nature==0.5.2) (1.3.0)
# Downloading qiskit_nature-0.5.2-py3-none-any.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 5.4 MB/s eta 0:00:0000:0100:01
# Downloading qiskit_algorithms-0.2.1-py3-none-any.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.9/306.9 kB 5.3 MB/s eta 0:00:00a 0:00:01
# Downloading qiskit_terra-0.46.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 6.0 MB/s eta 0:00:0000:0100:01m
# DEPRECATION: qiskit-nature 0.5.2 has a non-standard dependency specifier qiskit-terra>=0.22.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of qiskit-nature or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: qiskit-terra, qiskit-nature, qiskit-algorithms
#   Attempting uninstall: qiskit-nature
#     Found existing installation: qiskit-nature 0.7.2
#     Uninstalling qiskit-nature-0.7.2:
#       Successfully uninstalled qiskit-nature-0.7.2
#   Attempting uninstall: qiskit-algorithms
#     Found existing installation: qiskit-algorithms 0.3.1
#     Uninstalling qiskit-algorithms-0.3.1:
#       Successfully uninstalled qiskit-algorithms-0.3.1
# Successfully installed qiskit-algorithms-0.2.1 qiskit-nature-0.5.2 qiskit-terra-0.46.3
# Note: you may need to restart the kernel to use updated packages.

# %%
python -m venv qiskit2-env
source qiskit2-env/bin/activate
pip install --upgrade pip
pip install qiskit==2.0.0 qiskit-nature==0.7.2 qiskit-algorithms==0.3.1 pyscf
# Out:
#   Cell In[10], line 1
#     python -m venv qiskit2-env
#               ^
# SyntaxError: invalid syntax
